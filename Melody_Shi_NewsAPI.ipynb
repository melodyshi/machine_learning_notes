# %% [markdown]
# ### Assignment 1: Use the newsapi.org and IBM Watson API to extract entities that appear in the news
#
# #### Author: Melody Shi
# #### Written on: Sep 13, 2018

# %%
import requests
import pandas as pd
import json
import time

# %% [markdown]
# ### Part 1: Use a Web API to get URLs for news articles

# %%
"""
"  Gets a list of urls returned by news API with specified news source
"  @param 'source' A news source to be used for requesting
"  @return A list of top 10 urls
"""

def getNews(source):
    endpoint = "https://newsapi.org/v2/top-headlines"
    url_list = []
    parameters = {
    'sources' : source.strip().replace(' ','-'), #takes care of the white space in a query
    'language' : 'en',
    'apiKey' : 'aea8a8a56de048ecb78948268e10f6bd'  
    }
    try:
        resp = requests.get(endpoint,params = parameters).json()    
        for article in resp['articles']:
            url_list.append(article['url'])
    except Exception as ex:
        template = "An exception of type {0} occurred. Arguments:\n{1!r}"
        message = template.format(type(ex).__name__, ex.args)
        print(message)
        print("<----------Returning an empty list---------->")
    return url_list

# %%
getNews('bbc-news')
#getNews(' BBC News')  #works for conventional search query as well
# Out:
# ['http://www.bbc.co.uk/news/world-australia-45517450',
#  'http://www.bbc.co.uk/news/world-us-canada-45516937',
#  'http://www.bbc.co.uk/news/world-us-canada-45517406',
#  'http://www.bbc.co.uk/news/world-latin-america-45516234',
#  'http://www.bbc.co.uk/news/uk-45515013',
#  'http://www.bbc.co.uk/news/world-us-canada-45478934',
#  'http://www.bbc.co.uk/news/world-asia-45506882',
#  'http://www.bbc.co.uk/news/business-45514882',
#  'http://www.bbc.co.uk/news/world-europe-45513912',
#  'http://www.bbc.co.uk/news/world-us-canada-45511867']

# %% [markdown]
# ### Part 2: Analyze a news article using IBM Watson Natural Language Understanding API

# %%
"""
"  Gets a list of dictionaries representing entities returned by IBM-Watson API with specified url
"  @param 'url' A link to be used for requesting
"  @param 'source' A news source to be used for requesting; defaults to None
"  @param 'limit' An int that specifies the maximum of entities allowed to return; defaults to 10
"  @return A list of dictionaries representing entities
"""

def extractEntities(url, source=None, limit=10):
    list_of_dict = []
    username = '1705c559-5471-464d-8d17-fd449cea6669'
    pwd = 'CifcuEyJ71S1'
    
    endpoint = "https://gateway.watsonplatform.net/natural-language-understanding/api/v1/analyze"
    parameters = {
        'version': '2017-02-27',
    }
    headers = { 
        'Content-Type': 'application/json',
    }
    watson_options = {
      "url": url,
      "features": {
        "entities": {
          "sentiment": True,
          "emotion": True,
          "limit": limit
        }
      }
    }
    resp = requests.post(endpoint, 
                         data=json.dumps(watson_options), 
                         headers=headers, 
                         params=parameters, 
                         auth=(username, pwd) 
                        )
    
    for entity in resp.json()['entities']:        
        entity_dict = {}
        try:
            entity_dict['entity'] = entity['disambiguation']['name']  #IBM API may use dbpedia for name disambiguation
        except:
            entity_dict['entity'] = entity['text'] #if no disambiguation is made, get entity name using 'text' key 
        entity_dict['url'] = url
        if source != None:
            entity_dict['source'] = source #adds a source key only if source is specified
        entity_dict['relevance'] = entity['relevance'] 
        entity_dict['sentiment'] = entity['sentiment']['score']
        list_of_dict.append(entity_dict)
        
    return list_of_dict

# %%
url = 'http://www.bbc.co.uk/news/world-australia-45517450'
#extractEntities(url)
extractEntities(url,source='bbc-news') #with source specified
# Out:
# [{'entity': 'Scott Morrison',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.810038,
#   'sentiment': 0.698462},
#  {'entity': 'Fatman Scoop',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.277295,
#   'sentiment': 0.0},
#  {'entity': 'prime minister',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.228644,
#   'sentiment': 0.0},
#  {'entity': 'United States',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.207513,
#   'sentiment': 0.0},
#  {'entity': 'hundred dollar',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.207513,
#   'sentiment': 0.0},
#  {'entity': 'three weeks',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.207513,
#   'sentiment': 0.0},
#  {'entity': 'four hours',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.207513,
#   'sentiment': 0.0},
#  {'entity': '11-second',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.207513,
#   'sentiment': 0.0},
#  {'entity': '50 dollar',
#   'url': 'http://www.bbc.co.uk/news/world-australia-45517450',
#   'source': 'bbc-news',
#   'relevance': 0.207513,
#   'sentiment': 0.0}]

# %% [markdown]
# ### Part 3: Extract the entities that appear in the news and create a dashboard

# %%
"""
"  Builds a dataframe aggregating information returned by News API and IBM Watson API
"  @param 'source' A news source to be used for requesting
"  @return A dataframe with desired information
"""

def main(source):
    url_list = getNews(source)
    df = pd.DataFrame({'A' : []}) #creates an empty dataframe
    count = 0  #counts links processed
    for url in url_list:
        count += 1
        try:
            list_of_dict = extractEntities(url, source=source)
            df = pd.DataFrame(list_of_dict).append(df, ignore_index=True, sort=True)
            print("...{:.2f}% done, processing link {}".format((count/len(url))*100,count))
        except Exception as ex:
            template = "An exception of type {0} occurred for"+ url+". Arguments:\n{1!r}"
            message = template.format(type(ex).__name__, ex.args)
            print(message)
    return df.drop(columns=['A'])

# %%
df_wsj = main('the-wall-street-journal')
# Out:
# ...0.93% done, processing link 1
# ...1.74% done, processing link 2
# ...2.73% done, processing link 3
# ...4.08% done, processing link 4
# ...4.90% done, processing link 5
# ...4.72% done, processing link 6
# ...5.88% done, processing link 7
# ...6.78% done, processing link 8
# ...7.56% done, processing link 9
# ...8.20% done, processing link 10

# %%
df_ny = main('the-new-york-times')
# Out:
# ...1.19% done, processing link 1
# ...2.11% done, processing link 2
# ...3.66% done, processing link 3
# ...4.04% done, processing link 4
# ...5.38% done, processing link 5
# ...8.82% done, processing link 6
# ...10.61% done, processing link 7
# ...11.27% done, processing link 8
# ...12.50% done, processing link 9
# ...11.49% done, processing link 10

# %% [markdown]
# ### Result

# %%
pd.concat([df_wsj,df_ny], ignore_index=True)
# Out:
#                                     entity  relevance  sentiment  \
# 0                     Recep Tayyip Erdoğan   0.654717  -0.734879
# 1                                   17.75%   0.448016   0.000000
# 2                                      24%   0.448016   0.000000
# 3                    Amnesty International   0.814628  -0.426390
# 4                         Volkswagen Group   0.792835  -0.426390
# 5         Democratic Republic of the Congo   0.644475  -0.496871
# 6                         Congo—Apple Inc.   0.441636   0.000000
# 7                                two years   0.441636   0.000000
# 8                       General Motors Co.   0.752458  -0.512372
# 9                                       GM   0.643666  -0.535937
# 10                           United States   0.465161  -0.512372
# 11                           Goldman Sachs   0.911695   0.000000
# 12   president and chief operating officer   0.716339   0.000000
# 13                         chief executive   0.628422   0.000000
# 14                          Stephen Scherr   0.426000   0.000000
# 15                           Martin Chávez   0.420100   0.329803
# 16                            John Waldron   0.376274   0.415566
# 17                           David Solomon   0.376181   0.000000
# 18                                     CEO   0.309932   0.000000
# 19                         Brett Kavanaugh   0.891247  -0.308041
# 20                     Judiciary Committee   0.311957  -0.311722
# 21                        Dianne Feinstein   0.286282  -0.170214
# 22              Senate Judiciary Committee   0.264030   0.000000
# 23                                 senator   0.244605   0.000000
# 24                 Supreme Court of Canada   0.228445  -0.370508
# 25                    United States Senate   0.227500   0.000000
# 26         Federal Bureau of Investigation   0.217302  -0.115007
# 27      Supreme Court of the United States   0.210452  -0.372835
# 28                            Mazie Hirono   0.168546  -0.604167
# 29                          Facebook, Inc.   0.815229   0.000000
# ..                                     ...        ...        ...
# 123             Francis Becker Uncontested   0.797052   0.000000
# 124                    Fischer Uncontested   0.796291  -0.308484
# 125            Joseph Addabbo* Uncontested   0.791207   0.000000
# 126              Albert Stirpe Uncontested   0.768731   0.000000
# 127            Thomas Sullivan Uncontested   0.765486   0.000000
# 128                        President Trump   0.953229  -0.053819
# 129                       Paul J. Manafort   0.786724  -0.173724
# 130                        special counsel   0.446012  -0.481971
# 131                         Robert Mueller   0.384352  -0.511887
# 132                                  fraud   0.315198  -0.538779
# 133                              president   0.261987  -0.794304
# 134           United States District Court   0.261477  -0.308256
# 135                  Georgios Papadopoulos   0.259680   0.000000
# 136                           Andrew Cuomo   0.864190  -0.380496
# 137                          Cynthia Nixon   0.603310  -0.322902
# 138                     Albany, California   0.211229  -0.518107
# 139                               New York   0.199118  -0.404692
# 140                          New York City   0.197556  -0.367265
# 141                     Marcus J. Molinaro   0.168756  -0.429159
# 142            Senegalese Democratic Party   0.147906  -0.216422
# 143                           Bradley Tusk   0.131142  -0.308022
# 144                        President Trump   0.126974   0.229865
# 145             Massachusetts State Police   0.943967  -0.479250
# 146                Lawrence, Massachusetts   0.707292  -0.479310
# 147                               NiSource   0.489590  -0.516270
# 148                          Massachusetts   0.465726  -0.539210
# 149              Lawrence General Hospital   0.399343  -0.640514
# 150           North Andover, Massachusetts   0.384143  -0.469228
# 151                          North Andover   0.348045   0.000000
# 152                     Andover, Minnesota   0.341127   0.390587
#
#                       source  \
# 0    the-wall-street-journal
# 1    the-wall-street-journal
# 2    the-wall-street-journal
# 3    the-wall-street-journal
# 4    the-wall-street-journal
# 5    the-wall-street-journal
# 6    the-wall-street-journal
# 7    the-wall-street-journal
# 8    the-wall-street-journal
# 9    the-wall-street-journal
# 10   the-wall-street-journal
# 11   the-wall-street-journal
# 12   the-wall-street-journal
# 13   the-wall-street-journal
# 14   the-wall-street-journal
# 15   the-wall-street-journal
# 16   the-wall-street-journal
# 17   the-wall-street-journal
# 18   the-wall-street-journal
# 19   the-wall-street-journal
# 20   the-wall-street-journal
# 21   the-wall-street-journal
# 22   the-wall-street-journal
# 23   the-wall-street-journal
# 24   the-wall-street-journal
# 25   the-wall-street-journal
# 26   the-wall-street-journal
# 27   the-wall-street-journal
# 28   the-wall-street-journal
# 29   the-wall-street-journal
# ..                       ...
# 123       the-new-york-times
# 124       the-new-york-times
# 125       the-new-york-times
# 126       the-new-york-times
# 127       the-new-york-times
# 128       the-new-york-times
# 129       the-new-york-times
# 130       the-new-york-times
# 131       the-new-york-times
# 132       the-new-york-times
# 133       the-new-york-times
# 134       the-new-york-times
# 135       the-new-york-times
# 136       the-new-york-times
# 137       the-new-york-times
# 138       the-new-york-times
# 139       the-new-york-times
# 140       the-new-york-times
# 141       the-new-york-times
# 142       the-new-york-times
# 143       the-new-york-times
# 144       the-new-york-times
# 145       the-new-york-times
# 146       the-new-york-times
# 147       the-new-york-times
# 148       the-new-york-times
# 149       the-new-york-times
# 150       the-new-york-times
# 151       the-new-york-times
# 152       the-new-york-times
#
#                                                    url
# 0    https://www.wsj.com/articles/erdogan-moves-to-...
# 1    https://www.wsj.com/articles/erdogan-moves-to-...
# 2    https://www.wsj.com/articles/erdogan-moves-to-...
# 3    https://www.wsj.com/articles/smartphones-elect...
# 4    https://www.wsj.com/articles/smartphones-elect...
# 5    https://www.wsj.com/articles/smartphones-elect...
# 6    https://www.wsj.com/articles/smartphones-elect...
# 7    https://www.wsj.com/articles/smartphones-elect...
# 8    https://www.wsj.com/articles/gm-recalls-one-mi...
# 9    https://www.wsj.com/articles/gm-recalls-one-mi...
# 10   https://www.wsj.com/articles/gm-recalls-one-mi...
# 11   https://www.wsj.com/articles/goldman-sachs-nex...
# 12   https://www.wsj.com/articles/goldman-sachs-nex...
# 13   https://www.wsj.com/articles/goldman-sachs-nex...
# 14   https://www.wsj.com/articles/goldman-sachs-nex...
# 15   https://www.wsj.com/articles/goldman-sachs-nex...
# 16   https://www.wsj.com/articles/goldman-sachs-nex...
# 17   https://www.wsj.com/articles/goldman-sachs-nex...
# 18   https://www.wsj.com/articles/goldman-sachs-nex...
# 19   https://www.wsj.com/articles/kavanaugh-discuss...
# 20   https://www.wsj.com/articles/kavanaugh-discuss...
# 21   https://www.wsj.com/articles/kavanaugh-discuss...
# 22   https://www.wsj.com/articles/kavanaugh-discuss...
# 23   https://www.wsj.com/articles/kavanaugh-discuss...
# 24   https://www.wsj.com/articles/kavanaugh-discuss...
# 25   https://www.wsj.com/articles/kavanaugh-discuss...
# 26   https://www.wsj.com/articles/kavanaugh-discuss...
# 27   https://www.wsj.com/articles/kavanaugh-discuss...
# 28   https://www.wsj.com/articles/kavanaugh-discuss...
# 29   https://www.wsj.com/articles/facebook-to-start...
# ..                                                 ...
# 123  https://www.nytimes.com/interactive/2018/09/13...
# 124  https://www.nytimes.com/interactive/2018/09/13...
# 125  https://www.nytimes.com/interactive/2018/09/13...
# 126  https://www.nytimes.com/interactive/2018/09/13...
# 127  https://www.nytimes.com/interactive/2018/09/13...
# 128  https://www.nytimes.com/2018/09/13/us/politics...
# 129  https://www.nytimes.com/2018/09/13/us/politics...
# 130  https://www.nytimes.com/2018/09/13/us/politics...
# 131  https://www.nytimes.com/2018/09/13/us/politics...
# 132  https://www.nytimes.com/2018/09/13/us/politics...
# 133  https://www.nytimes.com/2018/09/13/us/politics...
# 134  https://www.nytimes.com/2018/09/13/us/politics...
# 135  https://www.nytimes.com/2018/09/13/us/politics...
# 136  https://www.nytimes.com/2018/09/13/nyregion/an...
# 137  https://www.nytimes.com/2018/09/13/nyregion/an...
# 138  https://www.nytimes.com/2018/09/13/nyregion/an...
# 139  https://www.nytimes.com/2018/09/13/nyregion/an...
# 140  https://www.nytimes.com/2018/09/13/nyregion/an...
# 141  https://www.nytimes.com/2018/09/13/nyregion/an...
# 142  https://www.nytimes.com/2018/09/13/nyregion/an...
# 143  https://www.nytimes.com/2018/09/13/nyregion/an...
# 144  https://www.nytimes.com/2018/09/13/nyregion/an...
# 145  https://www.nytimes.com/2018/09/13/us/lawrence...
# 146  https://www.nytimes.com/2018/09/13/us/lawrence...
# 147  https://www.nytimes.com/2018/09/13/us/lawrence...
# 148  https://www.nytimes.com/2018/09/13/us/lawrence...
# 149  https://www.nytimes.com/2018/09/13/us/lawrence...
# 150  https://www.nytimes.com/2018/09/13/us/lawrence...
# 151  https://www.nytimes.com/2018/09/13/us/lawrence...
# 152  https://www.nytimes.com/2018/09/13/us/lawrence...
#
# [153 rows x 5 columns]
