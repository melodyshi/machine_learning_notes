# %%
import numpy as np
an_array = np.array([[11,12],[21,22],[31,32]])
print(an_array)
# Out:
# [[11 12]
#  [21 22]
#  [31 32]]

# %%
filter = an_array > 15
filter
# Out:
# array([[False, False],
#        [ True,  True],
#        [ True,  True]], dtype=bool)

# %%
# compute mean by col
ave_col = an_array.mean(axis = 0)
print(ave_col)
# Out:
# [ 21.  22.]

# %%
# compute mean by row
ave_row = an_array.mean(axis = 1)
print(ave_row)
# Out:
# [ 11.5  21.5  31.5]

# %%
unsorted = np.random.randn(10)
print(unsorted)
type(unsorted)
# Out:
# [ 0.15726802 -0.50169655  1.17688522  0.34191395 -0.89735711  0.16348428
#   1.16074588 -0.74412239  0.89820733 -0.19172069]
# numpy.ndarray

# %%
sorted = np.array(unsorted)
print(sorted)
type(sorted)
sorted.sort()
print(sorted)
# Out:
# [ 0.15726802 -0.50169655  1.17688522  0.34191395 -0.89735711  0.16348428
#   1.16074588 -0.74412239  0.89820733 -0.19172069]
# [-0.89735711 -0.74412239 -0.50169655 -0.19172069  0.15726802  0.16348428
#   0.34191395  0.89820733  1.16074588  1.17688522]

# %%
unsorted.sort()
print(unsorted)
print(np.unique(unsorted))
# Out:
# [-0.89735711 -0.74412239 -0.50169655 -0.19172069  0.15726802  0.16348428
#   0.34191395  0.89820733  1.16074588  1.17688522]
# [-0.89735711 -0.74412239 -0.50169655 -0.19172069  0.15726802  0.16348428
#   0.34191395  0.89820733  1.16074588  1.17688522]

# %%
s1 = np.array(['desk','chair','bulb'])
s2 = np.array(['lamp','bulb','chair'])
print(np.intersect1d(s1,s2))
print(np.union1d(s1,s2))
print(np.setdiff1d(s1,s2))
print(np.in1d(s1,s2))
# Out:
# ['bulb' 'chair']
# ['bulb' 'chair' 'desk' 'lamp']
# ['desk']
# [False  True  True]

# %%
#satellite
import matplotlib
import numpy as ny
from scipy import misc
import matplotlib.pyplot as plt

# %%
from skimage import data
photo_data = misc.imread('sd-3layers.jpg')
type(photo_data)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize = (15,15))
plt.imshow(photo_data)
photo_data.shape
# Out:
# (3725, 4797, 3)

# %%
plt.show()

# %%
photo_data.size
# Out:
# 53606475

# %%
photo_data.mean()
# Out:
# 75.829935450894695

# %%
photo_data[150,250]
# Out:
# array([ 17,  35, 255], dtype=uint8)

# %%
photo_data[150,250,1]
# Out:
# 35

# %%
photo_data[150,250] =0
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
plt.show()

# %%
# row 200:800 G pixel to 255
photo_data[200:800,:,1] = 255
plt.figure(figsize=(10,10))
plt.imshow(photo_data)
plt.show()

# %%
photo_data = misc.imread('sd-3layers.jpg')

# %%
low_value_filter = photo_data<200
photo_data[low_value_filter] = 0
#plt.figure(figsize=(10,10))
plt.imshow(photo_data)
plt.show()

# %%
import numpy as np
rows_range = np.arange(len(photo_data))
cols_range = rows_range
photo_data[rows_range,cols_range]=255
plt.imshow(photo_data)
plt.show()

# %%
len(photo_data)
# Out:
# 3725

# %%
import pandas as pd
ser = pd.Series(data = [100,200,300,400,500],index=['tom','bob','nancy','dan','eric'])
ser
# Out:
# tom      100
# bob      200
# nancy    300
# dan      400
# eric     500
# dtype: int64

# %%
ser.index
# Out:
# Index(['tom', 'bob', 'nancy', 'dan', 'eric'], dtype='object')

# %%
ser['nancy']
ser.loc[['nancy','bob']]
# Out:
# nancy    300
# bob      200
# dtype: int64

# %%
ser[[4,3,1]]
# Out:
# eric    500
# dan     400
# bob     200
# dtype: int64

# %%
ser.iloc[2]
# Out:
# 300

# %%
'bob' in ser
# Out:
# True

# %%
200 in ser
# Out:
# False

# %%
ser*2
# Out:
# tom       200
# bob       400
# nancy     600
# dan       800
# eric     1000
# dtype: int64

# %%
ser**2
# Out:
# tom       10000
# bob       40000
# nancy     90000
# dan      160000
# eric     250000
# dtype: int64

# %%
ser[['nancy','eric']]**2
# Out:
# nancy     90000
# eric     250000
# dtype: int64

# %%
d={'one':pd.Series([100.,200.,300.],index = ['apple','ball','clock']),
  'two':pd.Series([111.,222.,333.,4444.],index = ['apple','ball','cerill','dancy'])}

# %%
df = pd.DataFrame(d)
df
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
print(df)
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'cerill', 'clock', 'dancy'], dtype='object')

# %%
pd.DataFrame(d,index = ['dancy','ball','apple'],columns = ['two','five'])
# Out:
#           two five
# dancy  4444.0  NaN
# ball    222.0  NaN
# apple   111.0  NaN

# %%
data = [{'alex':1,'joe':2},{'ema':5,'dora':10,'alice':20}]
print(data)
# Out:
# [{'alex': 1, 'joe': 2}, {'ema': 5, 'dora': 10, 'alice': 20}]

# %%
pd.DataFrame(data,index = ['orange','red'])
# Out:
#         alex  alice  dora  ema  joe
# orange   1.0    NaN   NaN  NaN  2.0
# red      NaN   20.0  10.0  5.0  NaN

# %%
pd.DataFrame(data,columns= ['joe','dora','alice'])
# Out:
#    joe  dora  alice
# 0  2.0   NaN    NaN
# 1  NaN  10.0   20.0

# %%
df['one']
# Out:
# apple     100.0
# ball      200.0
# cerill      NaN
# clock     300.0
# dancy       NaN
# Name: one, dtype: float64

# %%
df['three']=df['one']*df['two']
df
# Out:
#           one     two   flag    three
# apple   100.0   111.0  False  11100.0
# ball    200.0   222.0  False  44400.0
# cerill    NaN   333.0  False      NaN
# clock   300.0     NaN   True      NaN
# dancy     NaN  4444.0  False      NaN

# %%
df['flag']=df['one']>250
df
# Out:
#           one     two    three   flag
# apple   100.0   111.0  11100.0  False
# ball    200.0   222.0  44400.0  False
# cerill    NaN   333.0      NaN  False
# clock   300.0     NaN      NaN   True
# dancy     NaN  4444.0      NaN  False

# %%
three = df.pop('three')
three
# Out:
# apple     11100.0
# ball      44400.0
# cerill        NaN
# clock         NaN
# dancy         NaN
# Name: three, dtype: float64

# %%
df
# Out:
#           one     two   flag
# apple   100.0   111.0  False
# ball    200.0   222.0  False
# cerill    NaN   333.0  False
# clock   300.0     NaN   True
# dancy     NaN  4444.0  False

# %%
del df['two']

# %%
df
# Out:
#           one   flag  copy_of_one
# apple   100.0  False        100.0
# ball    200.0  False        200.0
# cerill    NaN  False          NaN
# clock   300.0   True        300.0
# dancy     NaN  False          NaN

# %%
df.insert(2,'copy_of_one',df['one'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-ad9e7befd9c9> in <module>()
# ----> 1 df.insert(2,'copy_of_one',df['one'])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    2421         value = self._sanitize_column(column, value, broadcast=False)
#    2422         self._data.insert(loc, column, value,
# -> 2423                           allow_duplicates=allow_duplicates)
#    2424
#    2425     def assign(self, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    3808         if not allow_duplicates and item in self.items:
#    3809             # Should this be a different kind of error??
# -> 3810             raise ValueError('cannot insert {}, already exists'.format(item))
#    3811
#    3812         if not isinstance(loc, int):
#
# ValueError: cannot insert copy_of_one, already exists

# %%
# Out:
#           one   flag  copy_of_one
# apple   100.0  False        100.0
# ball    200.0  False        200.0
# cerill    NaN  False          NaN
# clock   300.0   True        300.0
# dancy     NaN  False          NaN

# %%
df['one_upper_half']=df['one'][:2]

# %%
df
# Out:
#           one   flag  copy_of_one  one_upper_half
# apple   100.0  False        100.0           100.0
# ball    200.0  False        200.0           200.0
# cerill    NaN  False          NaN             NaN
# clock   300.0   True        300.0             NaN
# dancy     NaN  False          NaN             NaN

# %%
# !ls ./ml-20m
# Out:
# ls: ./ml-20m: No such file or directory

# %%
# !cat ./Users/Melody/Documents/movies.csv
# Out:
# cat: ./Users/Melody/Documents/movies.csv: No such file or directory

# %%
# !cat movies.csv | wc - l
# Out:
# wc: -: open: No such file or directory
# wc: l: open: No such file or directory
#        0       0       0 total
# cat: stdout: Broken pipe

# %%
# !head -5 movies.csv
# Out:
# movieId,title,genres
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance

# %%
import pandas as pd
movies = pd.read_csv("movies.csv")
print(type(movies))
movies.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv("ratings.csv",parse_dates=['timestamp'])
tags = pd.read_csv('tags.csv')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
row_0 = tags.iloc[0]
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,2000]]
# Out:
#       userId  movieId                tag
# 0         18     4141        Mark Waters
# 11        65     1783      noir thriller
# 2000     910    68554  conspiracy theory

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  8.732959e+06  8.732959e+06  8.732958e+06
# mean   2.996178e+04  9.133220e+03  3.526650e+00
# std    1.744420e+04  1.991965e+04  1.050475e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    1.479300e+04  9.040000e+02  3.000000e+00
# 50%    2.978500e+04  2.176000e+03  3.500000e+00
# 75%    4.502600e+04  4.823000e+03  4.000000e+00
# max    6.034800e+04  1.312580e+05  5.000000e+00

# %%
ratings['rating'].describe()
# Out:
# count    8.732958e+06
# mean     3.526650e+00
# std      1.050475e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
filter_1 = ratings['rating']>5
filter_1
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 8732929    False
# 8732930    False
# 8732931    False
# 8732932    False
# 8732933    False
# 8732934    False
# 8732935    False
# 8732936    False
# 8732937    False
# 8732938    False
# 8732939    False
# 8732940    False
# 8732941    False
# 8732942    False
# 8732943    False
# 8732944    False
# 8732945    False
# 8732946    False
# 8732947    False
# 8732948    False
# 8732949    False
# 8732950    False
# 8732951    False
# 8732952    False
# 8732953    False
# 8732954    False
# 8732955    False
# 8732956    False
# 8732957    False
# 8732958    False
# Name: rating, Length: 8732959, dtype: bool

# %%
filter_1.any()
# Out:
# False

# %%
filter_1.all()
# Out:
# False

# %%
filter_2=ratings['rating']>0
filter_2.any()
# Out:
# True

# %%
filter_2.all()
# Out:
# False

# %%
filter_3 = ratings['rating']<=0
filter_3
ratings[filter_2]
# Out:
#          userId  movieId  rating
# 0             1        2     3.5
# 1             1       29     3.5
# 2             1       32     3.5
# 3             1       47     3.5
# 4             1       50     3.5
# 5             1      112     3.5
# 6             1      151     4.0
# 7             1      223     4.0
# 8             1      253     4.0
# 9             1      260     4.0
# 10            1      293     4.0
# 11            1      296     4.0
# 12            1      318     4.0
# 13            1      337     3.5
# 14            1      367     3.5
# 15            1      541     4.0
# 16            1      589     3.5
# 17            1      593     3.5
# 18            1      653     3.0
# 19            1      919     3.5
# 20            1      924     3.5
# 21            1     1009     3.5
# 22            1     1036     4.0
# 23            1     1079     4.0
# 24            1     1080     3.5
# 25            1     1089     3.5
# 26            1     1090     4.0
# 27            1     1097     4.0
# 28            1     1136     3.5
# 29            1     1193     3.5
# ...         ...      ...     ...
# 8732928   60348     1200     3.5
# 8732929   60348     1208     4.5
# 8732930   60348     1210     4.0
# 8732931   60348     1213     3.5
# 8732932   60348     1214     4.0
# 8732933   60348     1215     3.0
# 8732934   60348     1219     3.0
# 8732935   60348     1221     4.0
# 8732936   60348     1222     4.0
# 8732937   60348     1233     2.0
# 8732938   60348     1240     4.5
# 8732939   60348     1246     3.5
# 8732940   60348     1252     2.0
# 8732941   60348     1258     4.0
# 8732942   60348     1259     4.0
# 8732943   60348     1265     3.0
# 8732944   60348     1266     4.0
# 8732945   60348     1270     4.0
# 8732946   60348     1275     3.0
# 8732947   60348     1288     3.0
# 8732948   60348     1291     3.0
# 8732949   60348     1356     3.5
# 8732950   60348     1358     4.0
# 8732951   60348     1370     3.0
# 8732952   60348     1374     4.0
# 8732953   60348     1376     3.0
# 8732954   60348     1378     4.0
# 8732955   60348     1387     4.0
# 8732956   60348     1393     3.5
# 8732957   60348     1500     3.0
#
# [8732958 rows x 3 columns]

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
tags = tags.dropna()

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
tags.shape
# Out:
# (465548, 3)

# %%
# %matplotlib inline

# %%
ratings.hist(column='rating',figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12064f2e8>]], dtype=object)

# %%
ratings.boxplot(column='rating',figsize=(15,20))

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[10:]
# Out:
# stylized                                                    1941
# quirky                                                      1906
# dark comedy                                                 1899
# classic                                                     1769
# psychology                                                  1754
# fantasy                                                     1703
# time travel                                                 1549
# romance                                                     1534
# visually appealing                                          1509
# disturbing                                                  1487
# aliens                                                      1428
# thought-provoking                                           1422
# social commentary                                           1417
# Nudity (Topless)                                            1400
# violence                                                    1336
# drugs                                                       1312
# Criterion                                                   1286
# true story                                                  1276
# nudity (topless)                                            1245
# adventure                                                   1243
# animation                                                   1229
# imdb top 250                                                1218
# CLV                                                         1199
# space                                                       1199
# dark                                                        1194
# superhero                                                   1171
# black comedy                                                1126
# post-apocalyptic                                            1116
# World War II                                                1116
# Betamax                                                     1093
#                                                             ...
# awww                                                           1
# author:Jay Parini                                              1
# QuÃƒÂ©bÃƒÂ©cois                                                1
# Marcellus Shale                                                1
# command line interface                                         1
# The Trolley Song                                               1
# weak female character                                          1
# tom shadyac                                                    1
# Shadow of a Doubt... with vampires                             1
# Vassiliki Khonsari                                             1
# intervius                                                      1
# Father-Daughter Relationship                                   1
# dishonest                                                      1
# thugs                                                          1
# cameo:John Landis                                              1
# actor playing self                                             1
# Tim Wolochatiuk                                                1
# no clear happy ending                                          1
# eye opener                                                     1
# E. Elias Merhige                                               1
# pure fight                                                     1
# Cate Blanchett !!!!                                            1
# dt: Solange du da bist                                         1
# WIRE HANGERS                                                   1
# Not Another Mingella Stretcher! We Hates Them!                 1
# politician cameo                                               1
# British Academy of Film and Television Arts Award Winner       1
# faux deep dialogue                                             1
# Ludwig Berger                                                  1
# Thief and Cop                                                  1
# Name: tag, Length: 38633, dtype: int64

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
is_highly_rated= ratings['rating']>=4.0
ratings[is_highly_rated].iloc[30:50,2]
# Out:
# 68     4.0
# 69     4.0
# 70     4.0
# 71     4.0
# 72     4.0
# 73     4.0
# 74     4.0
# 75     4.0
# 76     4.0
# 79     4.0
# 80     4.0
# 81     4.0
# 82     4.0
# 90     4.0
# 92     4.0
# 94     4.0
# 96     4.0
# 97     4.0
# 101    4.0
# 102    4.0
# Name: rating, dtype: float64

# %%
is_animation = movies['genres'].str.contains("Animation")

# %%
type(is_animation)
# Out:
# pandas.core.series.Series

# %%
print(is_animation.head())
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: genres, dtype: bool

# %%
movies[is_animation][5:15]
# Out:
#      movieId                                       title  \
# 310      313                   Swan Princess, The (1994)
# 360      364                       Lion King, The (1994)
# 388      392  Secret Adventures of Tom Thumb, The (1993)
# 547      551      Nightmare Before Christmas, The (1993)
# 553      558                      Pagemaster, The (1994)
# 582      588                              Aladdin (1992)
# 588      594      Snow White and the Seven Dwarfs (1937)
# 589      595                 Beauty and the Beast (1991)
# 590      596                            Pinocchio (1940)
# 604      610                          Heavy Metal (1981)
#
#                                               genres
# 310                               Animation|Children
# 360  Adventure|Animation|Children|Drama|Musical|IMAX
# 388                              Adventure|Animation
# 547               Animation|Children|Fantasy|Musical
# 553      Action|Adventure|Animation|Children|Fantasy
# 582      Adventure|Animation|Children|Comedy|Musical
# 588         Animation|Children|Drama|Fantasy|Musical
# 589  Animation|Children|Fantasy|Musical|Romance|IMAX
# 590               Animation|Children|Fantasy|Musical
# 604         Action|Adventure|Animation|Horror|Sci-Fi

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      104620
# 1.0      293958
# 1.5      120533
# 2.0      622482
# 2.5      389521
# 3.0     1871308
# 3.5      969196
# 4.0     2424998
# 4.5      671126
# 5.0     1265216

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId').mean()
average_rating.head()
# Out:
#            rating
# movieId
# 1        3.921502
# 2        3.208604
# 3        3.135499
# 4        2.903782
# 5        3.071211

# %%
movie_count = ratings[['movieId','rating']].groupby('movieId').count()

# %%
movie_count.head()
# Out:
#          rating
# movieId
# 1         21593
# 2          9681
# 3          5572
# 4          1190
# 5          5252

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags,on = 'movieId',how='inner')
t.head()
type(t)
# Out:
# pandas.core.frame.DataFrame

# %%
avg_ratings = ratings.groupby('movieId',as_index=False).mean()

# %%
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.921502
# 1        2  3.208604
# 2        3  3.135499
# 3        4  2.903782
# 4        5  3.071211

# %%
box_office = movies.merge(avg_ratings,on='movieId',how='inner')
box_office.tail()
# Out:
#        movieId                                 title              genres  \
# 22708   131031  La liga no es cosa de hombres (1972)  (no genres listed)
# 22709   131162         Por un puñado de besos (2014)       Drama|Romance
# 22710   131164                  Vietnam in HD (2011)                 War
# 22711   131166                     WWII IN HD (2009)  (no genres listed)
# 22712   131258                    The Pirates (2014)           Adventure
#
#        rating
# 22708     3.0
# 22709     2.0
# 22710     4.0
# 22711     4.0
# 22712     2.5

# %%
is_highly_rated = box_office['rating']>=4
box_office[is_highly_rated][-5:]
# Out:
#        movieId                                title                   genres  \
# 22698   130980  The Day That Lasted 21 Years (2012)              Documentary
# 22701   130996           The Beautiful Story (1992)  Adventure|Drama|Fantasy
# 22707   131023               That Sugar Film (2014)              Documentary
# 22710   131164                 Vietnam in HD (2011)                      War
# 22711   131166                    WWII IN HD (2009)       (no genres listed)
#
#        rating
# 22698     4.0
# 22701     5.0
# 22707     4.0
# 22710     4.0
# 22711     4.0

# %%
is_comedy = box_office['genres'].str.contains('Comedy')
box_office[is_comedy & is_highly_rated][-5:]
# Out:
#        movieId                           title          genres  rating
# 22614   129717    My Best Friend's Wife (1998)          Comedy     4.0
# 22615   129719              That's Life (1998)          Comedy     4.5
# 22616   129721  Chiedimi se sono felice (2000)    Comedy|Drama     4.0
# 22648   130081   Our Summer in Provence (2014)    Comedy|Drama     4.0
# 22697   130978         Love and Pigeons (1985)  Comedy|Romance     5.0

# %%
type(movies['genres'])
# Out:
# pandas.core.series.Series

# %%
ser = pd.Series([100,200,300,400,500],index = ['tom','bob','nancy','dan','eric'])

# %%
ser
# Out:
# tom      100
# bob      200
# nancy    300
# dan      400
# eric     500
# dtype: int64

# %%
ser.loc[['tom','bob']]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
ser[[0,1]]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
ser.iloc[[0,1]]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
ser[['tom','bob']]
# Out:
# tom    100
# bob    200
# dtype: int64

# %%
movies.head(7)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance

# %%
movies.head(n=7)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
